# %%
import pandas as pd
import pyodbc
# Out:
# /tmp/ipykernel_396614/616162634.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
wetchem = pd.read_csv("outputFiles/lv_filtered.csv")

# %%
df_spec = pd.read_csv("../DS-ML88/19_8_2022_global_spectra_datav2dot2_with_rw.csv", engine="c")

# %%
df_spec = df_spec.rename(columns={"Unnamed: 0":"sample_id"})

# %%
df_spec = df_spec.set_index("sample_id")

# %%
spc = df_spec.loc[(df_spec.index.isin(wetchem.sample_code))]

# %%
spc
# Out:
#                        522       524       526       528       530       532  \
# sample_id
# AGD207-408SA0706  2.096135  2.074343  2.077232  2.100555  2.109029  2.113436
# AGD207-431SA0001  2.154667  2.128691  2.090363  2.061056  2.036317  2.019021
# AGD207-431SA0002  2.412217  2.413204  2.360303  2.307860  2.296765  2.316080
# AGD207-431SA0003  2.059137  2.093001  2.136247  2.157497  2.152817  2.144714
# AGD207-431SA0004  2.279650  2.237250  2.218038  2.231755  2.238702  2.222442
# ...                    ...       ...       ...       ...       ...       ...
# CS301SA0020       2.045630  2.069787  2.128691  2.186521  2.180089  2.127234
# CS301SA0021       2.130854  2.172474  2.172629  2.144991  2.153000  2.181448
# CS301SA0023       2.174167  2.143292  2.162553  2.200258  2.199128  2.174309
# CW104SA0052       1.915089  1.907579  2.006204  2.047937  2.043367  2.039258
# CW104SA0053       2.077128  2.040786  2.043095  2.071373  2.064174  2.076678
#
# ...

# %%
wet = wetchem.loc[(wetchem.sample_code.isin(df_spec.index))]

# %%
wet
# Out:
#              sample_code  organic_carbon  total_nitrogen  aluminium  boron  \
# 0       AGD102-129SA0001             NaN             NaN        NaN    NaN
# 1       AGD102-130SA0001             NaN             NaN        NaN   2.89
# 2       AGD102-132SA0001             NaN             NaN        NaN    NaN
# 3       AGD102-133SA0001             NaN             NaN        NaN    NaN
# 4       AGD102-133SA0002             NaN             NaN        NaN    NaN
# ...                  ...             ...             ...        ...    ...
# 107496   I48-1-101SA0001             NaN             NaN        NaN   1.28
# 107497   I48-1-108SA0001             NaN             NaN        NaN   0.37
# 107498   I48-1-109SA0001             NaN             NaN        NaN   3.52
# 107499   I48-1-111SA0001             NaN             NaN        NaN   0.45
# 107500   I48-1-112SA0001             NaN             NaN        NaN   0.61
#
# ...

# %%
spc.to_csv("../MSSC_DVC/data/spc/spc.csv")

# %%
wet.to_csv("../MSSC_DVC/data/wetchem/wetchem.csv")

# %%
import rpy2.robjects as robjects

r = robjects.r
r['source']('trans.R')
waveletTrans = robjects.globalenv['transform']
from rpy2.robjects import pandas2ri


pandas2ri.activate()

# %%
df_trans = waveletTrans("D://CropNutsDocuments/MSSC_DVC/data/spc/spc.csv", "D://CropNutsDocuments/MSSC_DVC/data/spc/spc.csv")
# Out:
# R[write to console]: Error: cons memory exhausted (limit reached?)
#
# R[write to console]: Error: no more error handlers available (recursive errors?); invoking 'abort' restart
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 df_trans = waveletTrans("D://CropNutsDocuments/MSSC_DVC/data/spc/spc.csv", "D://CropNutsDocuments/MSSC_DVC/data/spc/spc.csv")
#
# File C:\Python310\lib\site-packages\rpy2\robjects\functions.py:204, in SignatureTranslatedFunction.__call__(self, *args, **kwargs)
#     202         v = kwargs.pop(k)
#     203         kwargs[r_k] = v
# --> 204 return (super(SignatureTranslatedFunction, self)
#     205         .__call__(*args, **kwargs))
#
# File C:\Python310\lib\site-packages\rpy2\robjects\functions.py:127, in Function.__call__(self, *args, **kwargs)
#     125     else:
# ...

# %%
import rpy2.robjects as robjects
r = robjects.r
r['source']('splits.R')
split = robjects.globalenv['split']
from rpy2.robjects import pandas2ri

try:
    os.mkdir("../MSSC_DVC/data/splits")
    os.mkdir("../MSSC_DVC/data/rds")
except:
    print()


pandas2ri.activate()

split("D://CropNutsDocuments/MSSC_DVC/data/spc/spc.csv","D://CropNutsDocuments/MSSC_DVC/data/rds/", "D://CropNutsDocuments/MSSC_DVC/data/splits")
# Out:
# R[write to console]: prospectr version 0.2.6 -- 'chicago'
#
# R[write to console]: check the github repository at: https://github.com/l-ramirez-lopez/prospectr/
#
# R[write to console]: data.table 1.14.6 using 4 threads (see ?getDTthreads).  Latest news: r-datatable.com
# [1] "chemical : exchangeable_acidity"
# R[write to console]: |--------------------------------------------------|
# |
# R[write to console]: ====
# R[write to console]: ===
# R[write to console]: ==
# R[write to console]: ==
# R[write to console]: ===
# R[write to console]: ==
# R[write to console]: ===
# R[write to console]: ==
# R[write to console]: ==
# R[write to console]: ===
# R[write to console]: ==
# R[write to console]: ==
# R[write to console]: ===
# R[write to console]: ==
# R[write to console]: ===
# R[write to console]: ==
# R[write to console]: ==
# R[write to console]: ===
# R[write to console]: ==
# R[write to console]: ===
# R[write to console]: |
